# %%
import pandas as pd
# csv file is comma separated values  file format for an excel file.

df = pd.read_csv(r"C:\Users\H\3D Objects\pandas\data.csv")
# r laganay se yeh raw string bn jayegi! aur error nhi ayega unicode se related.
df

# we can also skip header / rows
# Out:
#    Personal Evaluation  Test Fall 21       Unnamed: 1         Unnamed: 2  \
# 0                          Timestamp             name           relation
# 1                    2/10/2021 17:12             Shah             Others
# 2                    2/10/2021 17:25  Sameer Doultana  University friend
# 3                    2/10/2021 17:25    Adam ke ullad             Others
# 4                    2/10/2021 17:26   Ramsha Shakeel           Relative
# ..                               ...              ...                ...
# 66                    3/10/2021 9:41            Yahya           Relative
# 67                   3/10/2021 10:40     Rohail Ahmed  University friend
# 68                   3/10/2021 13:26               DH  University friend
# 69                   3/10/2021 13:32     Mohsin Satti  University friend
# 70                   3/10/2021 14:59            Mahad  University friend
#
#                                            Unnamed: 3  \
# ...

# %%
df1 =pd.read_csv(r"C:\Users\H\3D Objects\pandas\data.csv", skiprows=3)
df1

df2=pd.read_csv(r"C:\Users\H\3D Objects\pandas\data.csv", header=1) //1st row ko delete krne ka tareeka..
df2
# Out:
#           Timestamp             name           relation  \
# 0   2/10/2021 17:12             Shah             Others
# 1   2/10/2021 17:25  Sameer Doultana  University friend
# 2   2/10/2021 17:25    Adam ke ullad             Others
# 3   2/10/2021 17:26   Ramsha Shakeel           Relative
# 4   2/10/2021 17:27       Usama Ejaz  University friend
# ..              ...              ...                ...
# 65   3/10/2021 9:41            Yahya           Relative
# 66  3/10/2021 10:40     Rohail Ahmed  University friend
# 67  3/10/2021 13:26               DH  University friend
# 68  3/10/2021 13:32     Mohsin Satti  University friend
# 69  3/10/2021 14:59            Mahad  University friend
#
#                                                  good  \
# 0                                  You're hardworking
# 1   Helpful, Cooperative, well-mannered (& many more)
# 2                                         Tu muze hai
# 3                               Active and passionate
# ...

# %%
# df4 =pd.read_csv(r"C:\Users\H\3D Objects\pandas\data.csv", header = 1, names = ["T","N","R","G","B","S"])
# hum inko name dekar bhi read krskte hain!
df4
# Out:
#                   T                N                  R  \
# 0   2/10/2021 17:12             Shah             Others
# 1   2/10/2021 17:25  Sameer Doultana  University friend
# 2   2/10/2021 17:25    Adam ke ullad             Others
# 3   2/10/2021 17:26   Ramsha Shakeel           Relative
# 4   2/10/2021 17:27       Usama Ejaz  University friend
# ..              ...              ...                ...
# 65   3/10/2021 9:41            Yahya           Relative
# 66  3/10/2021 10:40     Rohail Ahmed  University friend
# 67  3/10/2021 13:26               DH  University friend
# 68  3/10/2021 13:32     Mohsin Satti  University friend
# 69  3/10/2021 14:59            Mahad  University friend
#
#                                                     G  \
# 0                                  You're hardworking
# 1   Helpful, Cooperative, well-mannered (& many more)
# 2                                         Tu muze hai
# 3                               Active and passionate
# ...

# %%
df5 =pd.read_csv(r"C:\Users\H\3D Objects\pandas\data.csv", nrows=4)
df5

# reading limited data from cvs file
# Out:
#   Personal Evaluation  Test Fall 21       Unnamed: 1         Unnamed: 2  \
# 0                         Timestamp             name           relation
# 1                   2/10/2021 17:12             Shah             Others
# 2                   2/10/2021 17:25  Sameer Doultana  University friend
# 3                   2/10/2021 17:25    Adam ke ullad             Others
#
#                                           Unnamed: 3  \
# 0                                               good
# 1                                 You're hardworking
# 2  Helpful, Cooperative, well-mannered (& many more)
# 3                                        Tu muze hai
#
#                    Unnamed: 4  \
# 0                         bad
# 1       You're an overthinker
# 2  Less social, less friendly
# 3                Charse jahaz
#
#                                           Unnamed: 5
# 0                                        suggestions
# 1                                         Keep calm
# ...

# %%
df1 =pd.read_csv(r"C:\Users\H\3D Objects\pandas\data.csv", na_values = ["Others"])
# useful trick to clean data.
# na main jo dengay wo na hojaye ga
df1
# Out:
#    Personal Evaluation  Test Fall 21       Unnamed: 1         Unnamed: 2  \
# 0                          Timestamp             name           relation
# 1                    2/10/2021 17:12             Shah                NaN
# 2                    2/10/2021 17:25  Sameer Doultana  University friend
# 3                    2/10/2021 17:25    Adam ke ullad                NaN
# 4                    2/10/2021 17:26   Ramsha Shakeel           Relative
# ..                               ...              ...                ...
# 66                    3/10/2021 9:41            Yahya           Relative
# 67                   3/10/2021 10:40     Rohail Ahmed  University friend
# 68                   3/10/2021 13:26               DH  University friend
# 69                   3/10/2021 13:32     Mohsin Satti  University friend
# 70                   3/10/2021 14:59            Mahad  University friend
#
#                                            Unnamed: 3  \
# ...

# %%
df2 =pd.read_csv(r"C:\Users\H\3D Objects\pandas\data.csv", na_values = ["Try"] )
df2
# Out:
#    Personal Evaluation  Test Fall 21       Unnamed: 1         Unnamed: 2  \
# 0                          Timestamp             name           relation
# 1                    2/10/2021 17:12             Shah             Others
# 2                    2/10/2021 17:25  Sameer Doultana  University friend
# 3                    2/10/2021 17:25    Adam ke ullad             Others
# 4                    2/10/2021 17:26   Ramsha Shakeel           Relative
# ..                               ...              ...                ...
# 66                    3/10/2021 9:41            Yahya           Relative
# 67                   3/10/2021 10:40     Rohail Ahmed  University friend
# 68                   3/10/2021 13:26               DH  University friend
# 69                   3/10/2021 13:32     Mohsin Satti  University friend
# 70                   3/10/2021 14:59            Mahad  University friend
#
#                                            Unnamed: 3  \
# ...

# %%
dfx =pd.read_csv(r"C:\Users\H\3D Objects\pandas\data.csv",header = 1, na_values = {
  "relation":["Relative"],
    "bad":["nothing","Nothing"]
    
#     yun dictionary ki form main bhi krskte hain data ko manipulate
})
dfx
# Out:
#           Timestamp             name           relation  \
# 0   2/10/2021 17:12             Shah             Others
# 1   2/10/2021 17:25  Sameer Doultana  University friend
# 2   2/10/2021 17:25    Adam ke ullad             Others
# 3   2/10/2021 17:26   Ramsha Shakeel                NaN
# 4   2/10/2021 17:27       Usama Ejaz  University friend
# ..              ...              ...                ...
# 65   3/10/2021 9:41            Yahya                NaN
# 66  3/10/2021 10:40     Rohail Ahmed  University friend
# 67  3/10/2021 13:26               DH  University friend
# 68  3/10/2021 13:32     Mohsin Satti  University friend
# 69  3/10/2021 14:59            Mahad  University friend
#
#                                                  good  \
# 0                                  You're hardworking
# 1   Helpful, Cooperative, well-mannered (& many more)
# 2                                         Tu muze hai
# 3                               Active and passionate
# ...

# %%
dfw = df5.to_csv("LimitedNewdata.csv")
dfw

# it will write the df5 file in a new file LImitedNewData,cvs

# %%
dfw = df5.to_csv("LimitedNewdata.txt" , index = False)
# by default index leta hai lekin yahan nhi lega as hmne isse false krdia hai 
dfw

# %%
dfw = df5.to_csv("LimitedNewdata.py")
dfw

# %%
dfw = df5.to_csv("LimitedNewdata.java")
dfw
# is trh kisi bhi file main csv file ka data write krskte hain

# %%
dfx.to_csv("nameWithGoodData.txt" ,index = False , columns = ['name','good'])

# %%
dfx.to_csv("nameWithBadData.txt" ,index = False , columns = ['name','bad'])

# %%
dfx.to_csv("nameWithSuggestionData.txt" ,index = False , columns = ['name','suggestions'])
